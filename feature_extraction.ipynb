# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
RAV = r"C:\Users\hp\Desktop\speech_emotion\Ravdess"
SAVEE = r"C:\Users\hp\Desktop\speech_emotion\Savee"
TESS = r"C:\Users\hp\Desktop\speech_emotion\TESS Toronto emotional speech set data"

# %%
dir_list = os.listdir(SAVEE)
emotion=[]
path = []
for i in dir_list:
    if i[-8:-6]=='_a':
        emotion.append('male_angry')
    elif i[-8:-6]=='_d':
        emotion.append('male_disgust')
    elif i[-8:-6]=='_f':
        emotion.append('male_fear')
    elif i[-8:-6]=='_h':
        emotion.append('male_happy')
    elif i[-8:-6]=='_n':
        emotion.append('male_neutral')
    elif i[-8:-6]=='sa':
        emotion.append('male_sad')
    elif i[-8:-6]=='su':
        emotion.append('male_surprise')
    else:
        emotion.append('male_error') 
    path.append(SAVEE + "\\"+i)

SAVEE_df = pd.DataFrame(emotion, columns = ['labels'])
SAVEE_df['source'] = 'SAVEE'
SAVEE_df = pd.concat([SAVEE_df, pd.DataFrame(path, columns = ['path'])], axis = 1)
SAVEE_df.labels.value_counts()
# Out:
# male_neutral     120
# male_angry        60
# male_disgust      60
# male_fear         60
# male_happy        60
# male_sad          60
# male_surprise     60
# Name: labels, dtype: int64

# %%
dir_list = os.listdir(RAV)
dir_list.sort()

emotion = []
gender = []
path = []
for i in dir_list:
    fname = os.listdir(RAV +"\\"+ i)
    for f in fname:
        part = f.split('.')[0].split('-')
        emotion.append(int(part[2]))
        temp = int(part[6])
        if temp%2 == 0:
            temp = "female"
        else:
            temp = "male"
        gender.append(temp)
        path.append(RAV +"\\"+ i + '\\' + f)

        
RAV_df = pd.DataFrame(emotion)
RAV_df = RAV_df.replace({1:'neutral', 2:'neutral', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'})
RAV_df = pd.concat([pd.DataFrame(gender),RAV_df],axis=1)
RAV_df.columns = ['gender','emotion']
RAV_df['labels'] =RAV_df.gender + '_' + RAV_df.emotion
RAV_df['source'] = 'RAVDESS'  
RAV_df = pd.concat([RAV_df,pd.DataFrame(path, columns = ['path'])],axis=1)
RAV_df = RAV_df.drop(['gender', 'emotion'], axis=1)
RAV_df.labels.value_counts()
# Out:
# male_neutral       144
# female_neutral     144
# male_happy          96
# male_sad            96
# male_angry          96
# male_fear           96
# male_disgust        96
# male_surprise       96
# female_happy        96
# female_sad          96
# female_angry        96
# female_fear         96
# female_disgust      96
# female_surprise     96
# Name: labels, dtype: int64

# %%
EmotionData_temp = pd.concat([SAVEE_df, RAV_df], axis = 0)
#print(EmotionData.labels.value_counts())

# %%
tess_directory_list=os.listdir(TESS)

file_emotion = []
file_path = []
print(TESS)
for dir in tess_directory_list:
    print(dir)
    directories = os.listdir(TESS +"\\"+ dir)
    for file in directories:
        #print(file)
        part = file.split('.')[0]
        part = part.split('_')[-1]
        if part=='ps':
            file_emotion.append('female_surprise')
        elif(part=="surprised"):
            file_emotion.append('female_surprise')
        elif(part=="fear"):
            file_emotion.append('female_fear')
        elif(part=="sad"):
            file_emotion.append('female_sad')
        elif(part=="angry"):
            file_emotion.append('female_angry')
        elif(part=="disgust"):
            file_emotion.append('female_disgust')
        elif(part=="nuetral"):
            file_emotion.append('female_neutral')
        else:
            file_emotion.append("female_" + part)
        file_path.append(TESS +"\\"+ dir + '\\' + file)
            
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['labels'])
# dataframe for path of files.
path_df = pd.DataFrame (file_path, columns=['path'])
Tess_df = pd.concat ([emotion_df, path_df], axis=1)
Tess_df['source'] = 'TESS'
Tess_df.head()

print(np.shape(Tess_df))
# Out:
# C:\Users\hp\Desktop\speech_emotion\TESS Toronto emotional speech set data
# OAF_angry
# OAF_disgust
# OAF_Fear
# OAF_happy
# OAF_neutral
# OAF_Pleasant_surprise
# OAF_Sad
# YAF_angry
# YAF_disgust
# YAF_fear
# YAF_happy
# YAF_neutral
# YAF_pleasant_surprised
# YAF_sad
# (2800, 3)

# %%
EmotionData = pd.concat([EmotionData_temp, Tess_df], axis = 0)
print(EmotionData.labels.value_counts())

EmotionData.to_csv("Data_path.csv",index=False)
# Out:
# female_neutral     544
# female_happy       496
# female_sad         496
# female_angry       496
# female_fear        496
# female_disgust     496
# female_surprise    496
# male_neutral       264
# male_angry         156
# male_disgust       156
# male_fear          156
# male_happy         156
# male_sad           156
# male_surprise      156
# Name: labels, dtype: int64

# %%
ref=pd.read_csv("Data_path.csv")
print (np.shape(ref))
# Out:
# (4720, 3)

# %%
df = pd.DataFrame(columns=['feature'])

counter=0

for index,path in enumerate(ref.path):
    source=ref.source[index]
    if source=="RAVDESS":
        d=2.5
        o=0.5
    if source=="SAVEE":
        d=5.5
        o=0.5
    if source=="TESS":
        d=1.5
        o=0.0
 
    X, sample_rate = librosa.load(path, res_type='kaiser_fast',duration=d,sr=4410,offset=o)
    sample_rate = np.array(sample_rate)
    mfcc=librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=13)
    mfcc_m=np.mean(mfcc,axis=1)  

    delta=librosa.feature.delta(mfcc)
    delta_m=np.mean(delta,axis=1)
    
    delta_delta=librosa.feature.delta(delta)
    delta_delta_m=np.mean(delta_delta,axis=1)
    
    feature = np.concatenate((mfcc_m, delta_m,delta_delta_m))

    df.loc[counter] = [feature]
    counter=counter+1   


print(len(df))
df.head()
# Out:
# 4720
#                                              feature
# 0  [-137.28888, 111.72388, -21.969687, -20.997446...
# 1  [-109.47295, 67.51979, -40.233547, -5.063055, ...
# 2  [-132.01605, 88.65481, -32.769714, -9.400137, ...
# 3  [-103.55519, 83.91427, -34.984425, -17.377562,...
# 4  [-143.46548, 69.09458, -28.198627, -13.793649,...

# %%
df = pd.concat([ref,pd.DataFrame(df['feature'].values.tolist())],axis=1)

# %%
df.head()
# Out:
#        labels source                                               path  \
# 0  male_angry  SAVEE  C:\Users\hp\Desktop\speech_emotion\Savee\DC_a0...
# 1  male_angry  SAVEE  C:\Users\hp\Desktop\speech_emotion\Savee\DC_a0...
# 2  male_angry  SAVEE  C:\Users\hp\Desktop\speech_emotion\Savee\DC_a0...
# 3  male_angry  SAVEE  C:\Users\hp\Desktop\speech_emotion\Savee\DC_a0...
# 4  male_angry  SAVEE  C:\Users\hp\Desktop\speech_emotion\Savee\DC_a0...
#
#             0           1          2          3          4         5  \
# 0 -137.288879  111.723877 -21.969687 -20.997446 -48.871670 -2.439504
# 1 -109.472954   67.519791 -40.233547  -5.063055 -39.719791  7.764367
# 2 -132.016052   88.654808 -32.769714  -9.400137 -35.487514  4.695376
# 3 -103.555191   83.914268 -34.984425 -17.377562 -56.287861  7.178759
# 4 -143.465485   69.094582 -28.198627 -13.793649 -44.961941 -1.339370
#
#            6  ...        29        30        31        32        33        34  \
# 0 -34.307919  ...  0.525392  0.662771  0.348220  0.523438  0.086971  0.450639
# 1 -25.280474  ...  0.489980  0.170700 -0.234358  0.578445 -0.081931  0.415396
# 2 -29.375397  ...  1.133303  1.217249 -0.244995  0.965961  0.180155  0.346001
# 3 -29.905863  ...  0.715701  0.453319  0.138438  0.757691  0.041856  0.765676
# 4 -27.697914  ...  0.685708  0.871115  0.040399  0.495775 -0.230098  0.320866
#
#          35        36        37        38
# 0 -0.046797  0.287537  0.018269  0.103508
# 1  0.141780  0.291497 -0.048786  0.022573
# 2  0.007635  0.802352 -0.099798  0.037451
# 3  0.114095  0.511521 -0.135596  0.007118
# 4 -0.022060  0.349066  0.242089  0.206005
#
# [5 rows x 42 columns]
